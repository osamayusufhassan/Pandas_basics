# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd

# %% [markdown]
# # 1. IMPORTING Files

# %% [markdown]
# ## Importing csv files

# %%
df = pd.read_csv('pokemon_data.csv')
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ## importing excel files

# %%
df1 = pd.read_excel('/content/pokemon_data.xlsx')
df1.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ## importing txt files

# %%
#df2 = pd.read_csv(r'C:\Users\HP\My JN Projects\Sample DATA\pandas-master\pokemon_data.txt', delimiter = '\t')
df2 = pd.read_csv('/content/pokemon_data.txt', delimiter = '\t')
df2.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# # 2. Reading Data from files

# %% [markdown]
# ## Reading Headers

# %%
print("---------csv file Headers--------")
print(df.columns)
#print("---------excel file Headers--------")
#print(df1.columns)
print("---------txt file Headers--------")
print(df2.columns)
# Out:
# ---------csv file Headers--------
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')
# ---------txt file Headers--------
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# ## Reading Specific column

# %%
df['Name'][0:20]
# Out:
# 0                     Bulbasaur
# 1                       Ivysaur
# 2                      Venusaur
# 3         VenusaurMega Venusaur
# 4                    Charmander
# 5                    Charmeleon
# 6                     Charizard
# 7     CharizardMega Charizard X
# 8     CharizardMega Charizard Y
# 9                      Squirtle
# 10                    Wartortle
# 11                    Blastoise
# 12      BlastoiseMega Blastoise
# 13                     Caterpie
# 14                      Metapod
# 15                   Butterfree
# 16                       Weedle
# 17                       Kakuna
# 18                     Beedrill
# 19        BeedrillMega Beedrill
# Name: Name, dtype: object

# %% [markdown]
# ## Reading Multiple columns

# %%
df[['Name','Type 1', 'HP']][0:20]
# Out:
#                          Name Type 1  HP
# 0                   Bulbasaur  Grass  45
# 1                     Ivysaur  Grass  60
# 2                    Venusaur  Grass  80
# 3       VenusaurMega Venusaur  Grass  80
# 4                  Charmander   Fire  39
# 5                  Charmeleon   Fire  58
# 6                   Charizard   Fire  78
# 7   CharizardMega Charizard X   Fire  78
# 8   CharizardMega Charizard Y   Fire  78
# 9                    Squirtle  Water  44
# 10                  Wartortle  Water  59
# 11                  Blastoise  Water  79
# 12    BlastoiseMega Blastoise  Water  79
# 13                   Caterpie    Bug  45
# 14                    Metapod    Bug  50
# 15                 Butterfree    Bug  60
# 16                     Weedle    Bug  40
# 17                     Kakuna    Bug  45
# 18                   Beedrill    Bug  65
# 19      BeedrillMega Beedrill    Bug  65

# %% [markdown]
# ## Reading Each Row

# %%
df.iloc[0]
# Out:
# #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object

# %% [markdown]
# ## Reading Multipe Rows

# %%
df.iloc[0:5]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ## Reading Specific cell/ location

# %%
df.iloc[1,1] # 1st row 1st column
# Out:
# 'Ivysaur'

# %%
df.iloc[2,3] # 2nd row 3rd column
# Out:
# 'Poison'

# %%
for index, row in df.iterrows():
    print(index, row['Type 1'])
# Out:
# 0 Grass
# 1 Grass
# 2 Grass
# 3 Grass
# 4 Fire
# 5 Fire
# 6 Fire
# 7 Fire
# 8 Fire
# 9 Water
# 10 Water
# 11 Water
# 12 Water
# 13 Bug
# 14 Bug
# 15 Bug
# 16 Bug
# 17 Bug
# 18 Bug
# 19 Bug
# 20 Normal
# 21 Normal
# 22 Normal
# 23 Normal
# 24 Normal
# 25 Normal
# 26 Normal
# 27 Normal
# 28 Poison
# 29 Poison
# 30 Electric
# 31 Electric
# 32 Ground
# 33 Ground
# 34 Poison
# 35 Poison
# 36 Poison
# 37 Poison
# 38 Poison
# 39 Poison
# 40 Fairy
# 41 Fairy
# 42 Fire
# 43 Fire
# 44 Normal
# 45 Normal
# 46 Poison
# 47 Poison
# 48 Grass
# 49 Grass
# 50 Grass
# 51 Bug
# 52 Bug
# 53 Bug
# 54 Bug
# 55 Ground
# 56 Ground
# 57 Normal
# 58 Normal
# 59 Water
# 60 Water
# 61 Fighting
# 62 Fighting
# 63 Fire
# 64 Fire
# 65 Water
# 66 Water
# 67 Water
# 68 Psychic
# 69 Psychic
# 70 Psychic
# 71 Psychic
# 72 Fighting
# 73 Fighting
# 74 Fighting
# 75 Grass
# 76 Grass
# 77 Grass
# 78 Water
# 79 Water
# 80 Rock
# 81 Rock
# 82 Rock
# 83 Fire
# 84 Fire
# 85 Water
# 86 Water
# 87 Water
# 88 Electric
# ...

# %%
for index, row in df.iterrows():
    print(index, "\t",row['Name'],'\t',row['Type 1'])
# Out:
# 0 	 Bulbasaur 	 Grass
# 1 	 Ivysaur 	 Grass
# 2 	 Venusaur 	 Grass
# 3 	 VenusaurMega Venusaur 	 Grass
# 4 	 Charmander 	 Fire
# 5 	 Charmeleon 	 Fire
# 6 	 Charizard 	 Fire
# 7 	 CharizardMega Charizard X 	 Fire
# 8 	 CharizardMega Charizard Y 	 Fire
# 9 	 Squirtle 	 Water
# 10 	 Wartortle 	 Water
# 11 	 Blastoise 	 Water
# 12 	 BlastoiseMega Blastoise 	 Water
# 13 	 Caterpie 	 Bug
# 14 	 Metapod 	 Bug
# 15 	 Butterfree 	 Bug
# 16 	 Weedle 	 Bug
# 17 	 Kakuna 	 Bug
# 18 	 Beedrill 	 Bug
# 19 	 BeedrillMega Beedrill 	 Bug
# 20 	 Pidgey 	 Normal
# 21 	 Pidgeotto 	 Normal
# 22 	 Pidgeot 	 Normal
# 23 	 PidgeotMega Pidgeot 	 Normal
# 24 	 Rattata 	 Normal
# 25 	 Raticate 	 Normal
# 26 	 Spearow 	 Normal
# 27 	 Fearow 	 Normal
# 28 	 Ekans 	 Poison
# 29 	 Arbok 	 Poison
# 30 	 Pikachu 	 Electric
# 31 	 Raichu 	 Electric
# 32 	 Sandshrew 	 Ground
# 33 	 Sandslash 	 Ground
# 34 	 Nidoran (Female) 	 Poison
# 35 	 Nidorina 	 Poison
# 36 	 Nidoqueen 	 Poison
# 37 	 Nidoran (Male) 	 Poison
# ...

# %%
df.loc[df['Type 1'] == "Fire"]
#df.loc[df['Type 1'] == "Grass"]
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %% [markdown]
# # 3. Sorting / Describing

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
#df.sort_values('Name')     # Alphabetical
df.sort_values('Name', ascending = False)   # inverted Alphabetical
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ## We can also sort by another feature

# %%
#df.sort_values(['Type 1','HP']) #...................ascending order
df.sort_values(['Type 1','HP'], ascending = [1,0]) #........Type 1 = ascending , HP = descending
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# # 4. Making Changes to Data

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ## Adding new columns

# %%
df['Total'] = df['HP']+df['Attack']+df['Defense']+df['Sp. Def']+df['Sp. Atk']+df['Speed']
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total  Grand_Total
# 0       65     45           1      False    318         3.18
# 1       80     60           1      False    405         4.05
# 2      100     80           1      False    525         5.25
# 3      120     80           1      False    625         6.25
# 4       50     65           1      False    309         3.09

# %%
df['Grand_Total']= df["Total"]*1.5
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total  Grand_Total
# 0       65     45           1      False    318        477.0
# 1       80     60           1      False    405        607.5
# 2      100     80           1      False    525        787.5
# 3      120     80           1      False    625        937.5
# 4       50     65           1      False    309        463.5

# %% [markdown]
# ## Removing Columns

# %%
df.drop(columns = ['Total'])
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Grand_Total
# ...

# %%
#second way of addition operation
df['Total'] = df.iloc[:,4:10].sum(axis = 1)
#df['Total'] = df.iloc[0:11,4:10].sum(axis = 1) # if we want to perform operation on just 10 rows
# axis = 1 means row addition
# iloc[starting row : ending row + 1, starting column:ending couml + 1]
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %% [markdown]
# ## Re-arranging Columns

# %%
#df.columns 
#shows in index #Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
       #'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Total', 'Grand_Total'],
      #dtype='object')


df.columns.values #shows in arrays
# Out:
# array(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Total',
#        'Grand_Total'], dtype=object)

# %%
dfarranged = df[['Name','Defense','Type 1']] #By column name
dfarranged.head()
# Out:
#                     Name  Defense Type 1
# 0              Bulbasaur       49  Grass
# 1                Ivysaur       63  Grass
# 2               Venusaur       83  Grass
# 3  VenusaurMega Venusaur      123  Grass
# 4             Charmander       43   Fire

# %%
dfarranged = df[df.columns.values[2:6]] # COLUMN 2-5
dfarranged.head()

#for rows
#dfarranged.iloc[2:4]
# Out:
#   Type 1  Type 2  HP  Attack
# 0  Grass  Poison  45      49
# 1  Grass  Poison  60      62
# 2  Grass  Poison  80      82
# 3  Grass  Poison  80     100
# 4   Fire     NaN  39      52

# %%
dfarranged = df[df.columns.values[-1]] # LAST COLUMN reverse indexing
dfarranged.head()
# Out:
# 0    477.0
# 1    607.5
# 2    787.5
# 3    937.5
# 4    463.5
# Name: Grand_Total, dtype: float64

# %%
# Moving The Last column to 4th index
cols = list(df.columns.values)
dfarranged = df[cols[0:4]+[cols[-1]]+cols[4:12]] 
dfarranged.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
